# %%
from evaluation.evaluation import *
from evaluation.Parkes_EGA_boundaries_T1DM import *
import numpy as np

# %%
# Numpy array with 1000 random values from 50 to 500
np.random.seed(0)
ground_truth = np.random.randint(50, 500, size=1000)

# Predictions are fround truth values plus a random value from -10 to 10
predictions = ground_truth + np.random.randint(-80, 80, size=1000)

# %%
a, b, c = bgISOAcceptableZone(ground_truth, predictions, fold = "test", plot = True)

# %%
AB, all, points = parkes_EGA_chart(ground_truth, predictions, 'testing')
